# %% [markdown]
# <a href="https://colab.research.google.com/github/eildes06/Randomlyworks/blob/main/Covid19analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid19=pd.read_csv("/content/worldometer_data.csv")

# %%
covid19.head(10)
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
# 5         Mexico  North America  1.290662e+08      462690    6590.0
# 6           Peru  South America  3.301632e+07      455409       NaN
# 7          Chile  South America  1.913251e+07      366671       NaN
# 8       Colombia  South America  5.093626e+07      357710       NaN
# 9          Spain         Europe  4.675665e+07      354530       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# ...

# %%
list_of_country=covid19["Country/Region"].unique()
list_of_country
# Out:
# array(['USA', 'Brazil', 'India', 'Russia', 'South Africa', 'Mexico',
#        'Peru', 'Chile', 'Colombia', 'Spain', 'Iran', 'UK', 'Saudi Arabia',
#        'Pakistan', 'Bangladesh', 'Italy', 'Turkey', 'Argentina',
#        'Germany', 'France', 'Iraq', 'Philippines', 'Indonesia', 'Canada',
#        'Qatar', 'Kazakhstan', 'Egypt', 'Ecuador', 'Bolivia', 'Sweden',
#        'Oman', 'Israel', 'Ukraine', 'Dominican Republic', 'Panama',
#        'Belgium', 'Kuwait', 'Belarus', 'UAE', 'Romania', 'Netherlands',
#        'Singapore', 'Guatemala', 'Portugal', 'Poland', 'Nigeria',
#        'Honduras', 'Bahrain', 'Japan', 'Armenia', 'Ghana', 'Kyrgyzstan',
#        'Afghanistan', 'Switzerland', 'Algeria', 'Azerbaijan', 'Morocco',
#        'Uzbekistan', 'Serbia', 'Moldova', 'Ireland', 'Kenya', 'Venezuela',
#        'Nepal', 'Austria', 'Costa Rica', 'Ethiopia', 'Australia',
#        'El Salvador', 'Czechia', 'Cameroon', 'Ivory Coast', 'S. Korea',
# ...

# %%
covid19.shape
# Out:
# (209, 16)

# %%
covid19.tail()
# Out:
#             Country/Region      Continent  Population  TotalCases  NewCases  \
# 204             Montserrat  North America      4992.0          13       NaN
# 205  Caribbean Netherlands  North America     26247.0          13       NaN
# 206       Falkland Islands  South America      3489.0          13       NaN
# 207           Vatican City         Europe       801.0          12       NaN
# 208         Western Sahara         Africa    598682.0          10       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 204          1.0        NaN            10.0           NaN          2.0
# 205          NaN        NaN             7.0           NaN          6.0
# 206          NaN        NaN            13.0           NaN          0.0
# 207          NaN        NaN            12.0           NaN          0.0
# 208          1.0        NaN             8.0           NaN          1.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# ...

# %%
covid19.info
# Out:
# <bound method DataFrame.info of             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
print(f"{covid19.shape[0]} rows & {covid19.shape[1]} columns in this dataset.")
# Out:
# 209 rows & 16 columns in this dataset.

# %%
print(f"{covid19['Continent'].nunique()} covid19 in dataset.")
# Out:
# 6 covid19 in dataset.

# %%
print(f"{covid19['Country/Region'].nunique()} covid19 in dataset.")
# Out:
# 209 covid19 in dataset.

# %%
print(f"{covid19['WHO Region'].nunique()} covid19 in dataset.")
# Out:
# 6 covid19 in dataset.

# %%
print(f"{covid19['Tot Cases/1M pop'].nunique()} covid19 in dataset.")
# Out:
# 202 covid19 in dataset.

# %%
covid19['WHO Region'].unique()
# Out:
# array(['Americas', 'South-EastAsia', 'Europe', 'Africa',
#        'EasternMediterranean', 'WesternPacific', nan], dtype=object)

# %%
covid19['Continent'].unique()
# Out:
# array(['North America', 'South America', 'Asia', 'Europe', 'Africa',
#        'Australia/Oceania', nan], dtype=object)

# %%
covid19.isnull()
# Out:
#      Country/Region  Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 0             False      False       False       False      True        False
# 1             False      False       False       False      True        False
# 2             False      False       False       False      True        False
# 3             False      False       False       False      True        False
# 4             False      False       False       False      True        False
# ..              ...        ...         ...         ...       ...          ...
# 204           False      False       False       False      True        False
# 205           False      False       False       False      True         True
# 206           False      False       False       False      True         True
# 207           False      False       False       False      True         True
# 208           False      False       False       False      True        False
#
# ...

# %%
covid19.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
covid19.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 204    False
# 205    False
# 206    False
# 207    False
# 208    False
# Length: 209, dtype: bool

# %%
covid19.duplicated().value_counts()
# Out:
# False    209
# dtype: int64

# %%
covid19.isnull().any()["WHO Region"]
# Out:
# True

# %%
covid19.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02     4.000000     188.000000    3.000000
# mean   3.041549e+07  9.171850e+04  1980.500000    3792.590426  300.000000
# std    1.047661e+08  4.325867e+05  3129.611424   15487.184877  451.199512
# min    8.010000e+02  1.000000e+01    20.000000       1.000000    1.000000
# 25%    9.663140e+05  7.120000e+02    27.500000      22.000000   40.500000
# 50%    7.041972e+06  4.491000e+03   656.000000     113.000000   80.000000
# 75%    2.575614e+07  3.689600e+04  2609.000000     786.000000  449.500000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02      3.000000  2.050000e+02        122.000000
# mean     5.887898e+04   1706.000000  2.766433e+04        534.393443
# std      2.566984e+05   2154.779803  1.746327e+05       2047.518613
# ...

# %%
covid19.TotalDeaths.describe()
# Out:
# count       188.000000
# mean       3792.590426
# std       15487.184877
# min           1.000000
# 25%          22.000000
# 50%         113.000000
# 75%         786.000000
# max      162804.000000
# Name: TotalDeaths, dtype: float64

# %%
covid19.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
covid19[covid19["Deaths/1M pop"] >= "Tot Cases/1M pop"][["Continent"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-aabd902268e8> in <module>()
# ----> 1 covid19[covid19["Deaths/1M pop"] >= "Tot Cases/1M pop"][["Continent"]]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __ge__(self, other)
#      50     @unpack_zerodim_and_defer("__ge__")
#      51     def __ge__(self, other):
# ---> 52         return self._cmp_method(other, operator.ge)
#      53
#      54     # -------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
(
    covid19
    .groupby('Continent')
    .agg({'TotalCases': 'sum'})
    .sort_values(by='TotalCases', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('Continent')
    .agg({'TotalDeaths': 'sum'})
    .sort_values(by='TotalDeaths', ascending=False)
    .round(2)
)
# Out:
#                    TotalDeaths
# Continent
# North America         229855.0
# Europe                205232.0
# South America         154885.0
# Asia                  100627.0
# Africa                 22114.0
# Australia/Oceania        281.0

# %%
(
    covid19
    .groupby('Continent')
    .agg({'TotalRecovered': 'sum'})
    .sort_values(by='TotalRecovered', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('Country/Region')
    .agg({'TotalCases': 'sum'})
    .sort_values(by='TotalCases', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('Country/Region')
    .agg({'TotalDeaths': 'sum'})
    .sort_values(by='TotalDeaths', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('Country/Region')
    .agg({'TotalRecovered': 'sum'})
    .sort_values(by='TotalRecovered', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('WHO Region')
    .agg({'TotalCases': 'sum'})
    .sort_values(by='TotalCases', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('WHO Region')
    .agg({'TotalDeaths': 'sum'})
    .sort_values(by='TotalDeaths', ascending=False)
    .round(2)
)

# %%
(
    covid19
    .groupby('WHO Region')
    .agg({'TotalRecovered': 'sum'})
    .sort_values(by='TotalRecovered', ascending=False)
    .round(2)
)
